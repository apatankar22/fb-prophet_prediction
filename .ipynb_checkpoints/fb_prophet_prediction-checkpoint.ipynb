# %%
import pandas as pd
from fbprophet import Prophet
import plotly.express as px
import plotly.io as pio
import yfinance as yf
import pandas_datareader as pdr
import datetime as dt
from datetime import date
import os
from PIL import Image

# %%
tech_stocks = ["FB", "AAPL", "AMZN", "TSLA", "GOOG", "NVDA", "NFLX"]
dfs = list()
prop_dfs = list()

# %%
for i in tech_stocks:
    if not os.path.isdir("output/" + str(i)):
        os.makedirs("output/" + str(i))
        
    if not os.path.isdir("output/" + str(i) + "/graphs"):
        os.makedirs("output/" + str(i) + "/graphs")
        
    if not os.path.isdir("output/" + str(i) + "/files"):
        os.makedirs("output/" + str(i) + "/files")    
        
        
    yf.pdr_override()
    today_date = date.today()
    dfs.append(pdr.get_data_yahoo(i, start = today_date - dt.timedelta(days = 5 * 365), end = today_date))

# %%
def initializer(df, c):
    if 'Date' not in df.columns:
        df = df.reset_index()
        
    f = open("output/" + tech_stocks[c - 1] + "/files/analysis.txt" , "w")
    #f = open("files/file" + str((c % len(tech_stocks)) + 1) + ".txt" , "w")
    f.write("Stock Information for Ticker: " + str(tech_stocks[c-1]) + "\n")
    f.write(df.mean().to_string())
    f.write("\n\n\n")
    f.write(df.describe().to_string())
    f.close()
    
    return df

# %%
def visualize(df, c):
    figs = list()
    figs.append(px.area(df, x = "Date", y = "Close"))
    figs.append(px.line(df, x = "Date", y = "Close"))
    figs.append(px.area(df, x = "Date", y = "Volume"))
    figs.append(px.line(df, x = "Date", y = "Volume"))   
    figs.append(px.bar(df, y = "Volume"))
    figs.append(px.box(df, y = "Close"))
    
    for i, j in enumerate(figs):
        j.write_image("output/" + str(tech_stocks[c-1]) + "/graphs/fig" + str(i+1) + ".png")

# %%
def preprocess(df):
    columns = ["Date", "Close"]
    prop_df = pd.DataFrame(df, columns = columns)
    prop_df = prop_df.rename(columns = {"Date": "ds", "Close": "y"})
    return prop_df

# %%
def forecaster(prop_df, c):
    m = Prophet()
    m.fit(prop_df)
    
    future = m.make_future_dataframe(periods = 36, freq = "M")
    forecast = m.predict(future)
    f = open("output/" + tech_stocks[c - 1] + "/files/analysis.txt" , "a")
    f.write("\n\n\n")
    f.write(forecast.to_string())
    f.close()
    pred_visualization(forecast, m, c)

# %%
def pred_visualization(fc, m, num):
    figs = list()
    figs.append(px.line(fc, x = "ds", y = "yhat"))
    figs.append(m.plot(fc, xlabel = "ds", ylabel = "y"))
    figs.append(m.plot_components(fc))
    for i, j in enumerate(figs):
        j.write_image("output/" + str(tech_stocks[num-1]) + "/graphs/forecast" + str(i+1) + ".png")

# %%
for i in range(len(dfs)):
    dfs[i] = initializer(dfs[i], i+1)
    visualize(dfs[i], i)
    prop_dfs.append(preprocess(dfs[i]))
    forecaster(prop_dfs[i], i+1)
# Out:
# /var/folders/s1/y8hjc_rd18g3zw5xh5l4_y8r0000gn/T/ipykernel_60247/1205042290.py:8: FutureWarning:
#
# DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -21.864
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       3628.94     0.0305106        3269.5           1           1      125
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       3656.66    0.00201947       449.924      0.2524      0.2524      240
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      250       3663.21   8.04625e-05       145.347   2.369e-07       0.001      335  LS failed, Hessian reset
#      284       3665.86   0.000196505       251.953   9.139e-07       0.001      411  LS failed, Hessian reset
#      299       3666.95   0.000498822       79.8236           1           1      428
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      382       3671.61   0.000144695       240.459    9.83e-07       0.001      571  LS failed, Hessian reset
#      399       3672.11   0.000299611       98.4863      0.6015      0.6015      590
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499        3674.9     0.0012026       94.1782       0.655           1      702
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599        3685.2     0.0026958       345.424           1           1      822
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       3687.24    0.00035392       346.527     0.08596      0.5014      949
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      772       3687.83   6.04722e-05       143.114   5.684e-07       0.001     1087  LS failed, Hessian reset
#      799       3688.22   0.000209183       110.726      0.9065      0.9065     1120
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      877       3689.34   5.01114e-05       133.787   3.246e-07       0.001     1250  LS failed, Hessian reset
#      899       3689.97   0.000354373        364.79      0.4356           1     1277
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      917       3690.24   0.000136717       201.876   1.256e-06       0.001     1339  LS failed, Hessian reset
#      989       3690.63   4.90779e-05       69.7375   1.947e-07       0.001     1462  LS failed, Hessian reset
#      999       3690.64   2.22754e-05       62.7354           1           1     1478
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       3691.44    0.00250311       192.036           1           1     1608
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       3695.73    0.00181556       110.185      0.2225           1     1728
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299        3696.4   0.000615784       117.674           1           1     1857
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399       3697.01    0.00117574       113.097           1           1     1994
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1417       3697.29   4.47753e-05       116.771   3.673e-07       0.001     2060  LS failed, Hessian reset
#     1458       3697.41   1.54426e-05       78.7818   2.059e-07       0.001     2152  LS failed, Hessian reset
#     1479       3697.41   1.77766e-07       57.4438      0.1021           1     2185
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/s1/y8hjc_rd18g3zw5xh5l4_y8r0000gn/T/ipykernel_60247/2046096847.py in <module>
#       3     visualize(dfs[i], i)
#       4     prop_dfs.append(preprocess(dfs[i]))
# ----> 5     forecaster(prop_dfs[i], i+1)
#
# /var/folders/s1/y8hjc_rd18g3zw5xh5l4_y8r0000gn/T/ipykernel_60247/2923438786.py in forecaster(prop_df, c)
#       9     f.write(forecast.to_string())
#      10     f.close()
# ---> 11     pred_visualization(forecast, m, c)
#
# /var/folders/s1/y8hjc_rd18g3zw5xh5l4_y8r0000gn/T/ipykernel_60247/2311440935.py in pred_visualization(fc, m, num)
#       5     figs.append(m.plot_components(fc))
#       6     for i, j in enumerate(figs):
# ----> 7         j.write_image("output/" + str(tech_stocks[num-1]) + "/graphs/forecast" + str(i+1) + ".png")
#
# AttributeError: 'Figure' object has no attribute 'write_image'
